# %% [markdown]
# ### this is a test cell

# %%
import pandas as pd

# %%
file_path="C:\\Users\\christo.strydom\\github_repos\\nb_dd\\data\\"

# %%
pd.read_excel(io=file_path+"20201130_New_Business_Daily_Dashboard_New_VS_FY2021_MIP_VS_SNo_NM.xlsx",sheet_name="Kaelo Raw_Data")
# Out:
#                           Client                   BDC       CRM  \
# 0     ARB Electrical Wholesalers  Kirsten Craig Arnold       NaN
# 1                            NWK  Kirsten Craig Arnold    Liezle
# 2         Fidelity Service Group  Kirsten Craig Arnold    Zanele
# 3                        Nedbank  Kirsten Craig Arnold       NaN
# 4                          Tsebo  Kirsten Craig Arnold  Marianna
# ...                          ...                   ...       ...
# 2016                         NaN                   NaN       NaN
# 2017                         NaN                   NaN       NaN
# 2018                         NaN                   NaN       NaN
# 2019                         NaN                   NaN       NaN
# 2020                         NaN                   NaN       NaN
#
#                                  Intermediary                     Client.1  \
# 0                            Alexander Forbes   ARB Electrical Wholesalers
# ...
